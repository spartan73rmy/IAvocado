# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
img_height = 180
img_width = 180

# %% [markdown]
# ### Load Model

# %%
model = tf.keras.models.load_model('saved_model/model2')

# Check its architecture
#model.summary()

# %%
import pathlib

data_dir=r"C:\Users\spart\Desktop\Source\IAvocado\testing" #rename images plath
data_dir = pathlib.Path(data_dir)

# %%
images=list(data_dir.glob('*/*.jpg'));
print(len(images))
# Out:
# 1

# %%
arr=[];
plt.figure(figsize=(5, 5))

for i in images:
    image = tf.keras.preprocessing.image.load_img(str(i),target_size = (img_height,img_width))
    input_arr = keras.preprocessing.image.img_to_array(image)    
    input_arr = np.array([input_arr])  # Convert single image to a batch.
    arr.append(input_arr);
    predictions = model.predict(input_arr)
    print(predictions)
    res= "Aguacate tierno" if(predictions[0][0]>predictions[0][1]) else "Aguacate Maduro"
    print(res)
    imgplot = plt.imshow(image)
    plt.show()
# Out:
# [[10.312135  -6.5261116]]
# Aguacate tierno
